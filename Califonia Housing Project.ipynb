# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("datahub\cal_housing.csv")
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
df["ocean_proximity"].unique()
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %%
df["ocean_proximity"].value_counts()
# Out:
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %%
df.describe().transpose()
#Low std indicates that the housing is widely distributed
# Out:
#                       count           mean            std         min  \
# longitude           20640.0    -119.569704       2.003532   -124.3500
# latitude            20640.0      35.631861       2.135952     32.5400
# housing_median_age  20640.0      28.639486      12.585558      1.0000
# total_rooms         20640.0    2635.763081    2181.615252      2.0000
# total_bedrooms      20433.0     537.870553     421.385070      1.0000
# population          20640.0    1425.476744    1132.462122      3.0000
# households          20640.0     499.539680     382.329753      1.0000
# median_income       20640.0       3.870671       1.899822      0.4999
# median_house_value  20640.0  206855.816909  115395.615874  14999.0000
#
#                             25%          50%           75%          max
# longitude             -121.8000    -118.4900    -118.01000    -114.3100
# latitude                33.9300      34.2600      37.71000      41.9500
# ...

# %%
sns.countplot(data=df,x="ocean_proximity");

# %%
df.hist(figsize=(20,15));

# %%
sns.boxplot(data=df,x="median_house_value")
# Out:
# <AxesSubplot: xlabel='median_house_value'>

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
sns.scatterplot(data=df,x="housing_median_age",y="median_house_value");

# %%
# Finding the percentage of missing value 
round((df.isnull().sum()/len(df))*100,2)
# Out:
# longitude             0.0
# latitude              0.0
# housing_median_age    0.0
# total_rooms           0.0
# total_bedrooms        1.0
# population            0.0
# households            0.0
# median_income         0.0
# median_house_value    0.0
# ocean_proximity       0.0
# dtype: float64

# %%
#Plot is similar to the map of califonia. 
plt.figure(figsize=(12,5))
sns.scatterplot(data=df,x="latitude",y="longitude",hue="ocean_proximity");

# %% [markdown]
# ### Data Preparation

# %%
# We split the data, drop the entire column with the exception of column for prediction 
X=df.drop("median_house_value",axis=1)
y= df["median_house_value"]

# %%
X.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income ocean_proximity
# 0       322.0       126.0         8.3252        NEAR BAY
# 1      2401.0      1138.0         8.3014        NEAR BAY
# 2       496.0       177.0         7.2574        NEAR BAY
# 3       558.0       219.0         5.6431        NEAR BAY
# 4       565.0       259.0         3.8462        NEAR BAY

# %%
y.head()
# Out:
# 0    452600.0
# 1    358500.0
# 2    352100.0
# 3    341300.0
# 4    342200.0
# Name: median_house_value, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=34)

# %%
X_train.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 7067     -118.01     33.95                36.0       1579.0           290.0
# 18972    -122.00     38.23                 1.0       2062.0           343.0
# 10877    -117.88     33.72                38.0       1421.0           300.0
# 20440    -118.77     34.24                 6.0      16222.0          2309.0
# 15424    -117.27     33.20                34.0       1852.0           322.0
#
#        population  households  median_income ocean_proximity
# 7067        816.0       276.0         4.4318       <1H OCEAN
# 18972       872.0       268.0         5.2636          INLAND
# 10877      1236.0       263.0         3.9844       <1H OCEAN
# 20440      6700.0      2080.0         6.4963       <1H OCEAN
# 15424       978.0       332.0         4.3542       <1H OCEAN

# %%
X_train.shape
# Out:
# (16512, 9)

# %%
len(df)*80/100
# Out:
# 16512.0

# %%
X_test.shape
# Out:
# (4128, 9)

# %%
len(df)*20/100
# Out:
# 4128.0

# %%
X_test.isnull().sum()
# Out:
# longitude              0
# latitude               0
# housing_median_age     0
# total_rooms            0
# total_bedrooms        52
# population             0
# households             0
# median_income          0
# ocean_proximity        0
# dtype: int64

# %%
X_train.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        155
# population              0
# households              0
# median_income           0
# ocean_proximity         0
# dtype: int64

# %%
num_X_train = X_train.drop("ocean_proximity",axis =1)
num_X_test = X_test.drop("ocean_proximity",axis =1)

# %%
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# %%
#Univariate imputer for completing missing values with simple strategies.
si = SimpleImputer(strategy="median")
# Training & learning the dataset.It has learned from the training dataset & can be used to tranform the test 
si.fit(num_X_train)
# Out:
# SimpleImputer(strategy='median')

# %%
si.transform(num_X_train)
# Out:
# array([[-1.18010e+02,  3.39500e+01,  3.60000e+01, ...,  8.16000e+02,
#          2.76000e+02,  4.43180e+00],
#        [-1.22000e+02,  3.82300e+01,  1.00000e+00, ...,  8.72000e+02,
#          2.68000e+02,  5.26360e+00],
#        [-1.17880e+02,  3.37200e+01,  3.80000e+01, ...,  1.23600e+03,
#          2.63000e+02,  3.98440e+00],
#        ...,
#        [-1.17870e+02,  3.36000e+01,  3.50000e+01, ...,  7.82000e+02,
#          4.11000e+02,  5.11550e+00],
#        [-1.18400e+02,  3.41100e+01,  3.20000e+01, ...,  1.56700e+03,
#          6.97000e+02,  1.50001e+01],
#        [-1.18000e+02,  3.38400e+01,  2.90000e+01, ...,  2.41300e+03,
#          6.19000e+02,  2.81690e+00]])

# %%
# Avoid fits on your test data to prevent leak of data
si.transform(num_X_test)
# Out:
# array([[-1.1812e+02,  3.4150e+01,  2.2000e+01, ...,  1.0050e+03,
#          4.4300e+02,  3.0119e+00],
#        [-1.1972e+02,  3.6750e+01,  2.7000e+01, ...,  8.6900e+02,
#          3.3700e+02,  3.9514e+00],
#        [-1.1734e+02,  3.3940e+01,  1.3000e+01, ...,  3.3820e+03,
#          1.1760e+03,  5.5563e+00],
#        ...,
#        [-1.2044e+02,  3.4910e+01,  1.2000e+01, ...,  1.2000e+03,
#          4.4200e+02,  5.2990e+00],
#        [-1.2122e+02,  3.7970e+01,  3.7000e+01, ...,  1.1210e+03,
#          3.3700e+02,  2.4010e+00],
#        [-1.1928e+02,  3.4450e+01,  3.6000e+01, ...,  1.5050e+03,
#          5.4700e+02,  2.4595e+00]])

# %%
Encoding 
Integer - Uses numbers to rep elements eg, 1H Ocean = 1, INLAND = 2 etc
Ordinal - works with order 1>2,2>3
frequency/mode - Number of times and elmt has appeared/uses value_counts to rep 
label encoding - 0 - Female ,1-Male
onehot - It creates a dummy variable , eg 
     can, us , uk 
    can1   0    0
    us0    1    0
    uk0    0    1
